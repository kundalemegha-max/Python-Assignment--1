# %% [markdown]
# <a href="https://colab.research.google.com/github/kundalemegha-max/Python-Assignment--1/blob/main/if_else_elif_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1=int(input(("enter the number:")))
num2=int(input(("enter the number:")))
if num1>num2:
  print("num1 is greater than num2")
elif num1<num2:
  print("num1 is less than num2")
else:
  print("The numbers are equal")
# Out:
# enter the number:2
# enter the number:4
# num1 is less than num2

# %%
#get the frist number from the user
num1=float(input("enter the frist number:"))

#get the second number from the user
num2=float(input("enter the second number:"))

# campare the numbers and print the larger one
if num1>num2:
    print(f" the lager number is:{num1}")


elif num2>num1:
    print(f"the lager number is:{num2}")

else:
    print("both numbers are equal.")
# Out:
# enter the frist number:54
# enter the second number:43
#  the lager number is:54.0
